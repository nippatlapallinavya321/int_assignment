# %% [markdown]
# # test = "Edukron Data Science and Data Engineering Batch 2026"

# %%
text[0:7]
text[-53:-45]
# Out:
# 'Edukron'

# %%
text[8:12]
text[-44:-40]
# Out:
# 'Data'

# %%
text[13:20]
text[-39:-32]
# Out:
# 'Science'

# %%
text[21:24]
text[-31:-28]
# Out:
# 'and'

# %%
text[25:41]
text[-27:-11]
# Out:
# 'Data Engineering'

# %%
text[30:40]
text[-22:-11]
# Out:
# 'Engineering'

# %%
text[42:47]
text[-10:-5]
# Out:
# 'Batch'

# %%
text[48:]
text[-4:]
# Out:
# '2026'

# %%
text[13:29]
text[-39:-23]
# Out:
# 'Science and Data'

# %%
text[8:47]
text[-44:-5]
# Out:
# 'Data Science and Data Engineering Batch'
