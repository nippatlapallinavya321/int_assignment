# %% [markdown]
# Section 1: Lambda Expressions — 20 Questions
#
# Question 1:Write a lambda expression to calculate the square of number.

# %%
number = 8
square = lambda x: x**2
print(square(number))
# Out:
# 64

# %% [markdown]
# Question 2:Write a lambda expression to calculate the cube of number.

# %%
number = 5
cube = lambda x: x**3
print(cube(number))
# Out:
# 125

# %% [markdown]
# Question 3:Write a lambda expression to add a and b.

# %%
a = 25
b = 17
add = lambda a, b: a+b
print(add(a, b))
# Out:
# 42

# %% [markdown]
# Question 4:Write a lambda expression to subtract b from a.

# %%
a = 50
b = 18
subtract = lambda a, b: a-b
print(subtract(a, b))
# Out:
# 32

# %% [markdown]
# Question 5:Write a lambda expression to multiply a and b.

# %%
a = 12
b = 9
multiply = lambda a, b: a*b
print(multiply(a, b))

# %% [markdown]
# Question 6:Write a lambda expression to divide a by b.

# %%
a = 100
b = 4
divide = lambda a, b: a/b
print(divide(a, b))
# Out:
# 25.0

# %% [markdown]
# Question 7:Write a lambda expression to return the larger number.

# %%
a = 72
b = 91
larger = lambda a, b: max(a, b)
print(larger(a, b))
# Out:
# 91

# %% [markdown]
# Question 8:Write a lambda expression to return the smaller number.

# %%
a = 46
b = 28
smaller = lambda a, b: min(a, b)
print(smaller(a, b))
# Out:
# 28

# %% [markdown]
# Question 9:Write a lambda expression that returns True when the number is even and False otherwise.

# %%
number = 34
even = lambda number: number%2==0
print(even(number))
# Out:
# True

# %% [markdown]
# Question 10:Write a lambda expression that returns True when the number is odd and False otherwise.

# %%
number = 27
odd = lambda number: number%2!=0
print(odd(number))
# Out:
# True

# %% [markdown]
# Question 11:Write a lambda expression to calculate the area of a rectangle.

# %%
length = 12
width = 8
rectangle = lambda length, width: length*width
print(rectangle(length, width))
# Out:
# 96

# %% [markdown]
# Question 12:Write a lambda expression to calculate the area of a circle using 3.14.

# %%
radius = 7
circle = lambda radius: 3.14*radius**2
print(circle(radius))
# Out:
# 153.86

# %% [markdown]
# Question 13:Write a lambda expression to calculate the perimeter of a rectangle.

# %%
length = 15
width = 10
rectangle = lambda length, width: 2*(length+width)
print(rectangle(length, width))
# Out:
# 50

# %% [markdown]
# Question 14:Write a lambda expression to convert Celsius into Fahrenheit.

# %%
celsius = 35
fahrenheit = lambda celsius: (celsius*9/5)+32
print(fahrenheit(celsius))
# Out:
# 95.0

# %% [markdown]
# Question 15:Write a lambda expression to convert Fahrenheit into Celsius.

# %%
fahrenheit = 105
celsius = lambda fahrenheit: (fahrenheit-32)*5/9
print(celsius(fahrenheit))
# Out:
# 40.55555555555556

# %% [markdown]
# Question 16:Write a lambda expression to return the length of the string.

# %%
word = "python"
length = lambda word: len(word)
print(length(word))
# Out:
# 6

# %% [markdown]
# Question 17:Write a lambda expression to return the first character of the string.

# %%
word = "Programing"
first = lambda word: word[0]
print(first(word))
# Out:
# P

# %% [markdown]
# Question 18:Write a lambda expression to return the last character of the string.

# %%
word = "databricks"
last = lambda word: word[-1]
print(last(word))
# Out:
# s

# %% [markdown]
# Question 19:Write a lambda expression to return the absolute value of the number without using abs().

# %%
number = -45
absolute = lambda number: number*(-1) if number<0 else number
print(absolute(number))
# Out:
# 45

# %% [markdown]
# Question 20:Write a lambda expression that returns:
#
# "Distinction" when marks are 75 or above "Pass" when marks are 40 to 74 "Fail" when marks are below 40

# %%
marks = 72
result = lambda marks: "Distinction" if marks>=75 else "Pass" if marks>=40 else "Fail"
print(result(marks))
# Out:
# Pass

# %% [markdown]
# Section 2: map() — 20 Questions
#
# Question 1 numbers = [1, 2, 3, 4, 5, 6] Using map() and a lambda expression, calculate the square of every number.

# %%
numbers = [1, 2, 3, 4, 5, 6]
squared = list(map(lambda x: x**2, numbers))
print(squared)
# Out:
# [1, 4, 9, 16, 25, 36]

# %% [markdown]
# Question 2 numbers = [2, 3, 4, 5, 6] Using map() and a lambda expression, calculate the cube of every number.

# %%
numbers = [2, 3, 4, 5, 6]
cubed = list(map(lambda x: x**3, numbers))
print(cubed)
# Out:
# [8, 27, 64, 125, 216]

# %% [markdown]
# Question 3 numbers = [10, 20, 30, 40, 50] Using map(), add 5 to every number.

# %%
numbers = [10, 20, 30, 40, 50]
result = list(map(lambda x: x + 5, numbers))
print(result)
# Out:
# [15, 25, 35, 45, 55]

# %% [markdown]
# Question 4 numbers = [15, 25, 35, 45, 55] Using map(), subtract 10 from every number.

# %%
numbers = [15, 25, 35, 45, 55]
result = list(map(lambda x: x - 10, numbers))
print(result)
# Out:
# [5, 15, 25, 35, 45]

# %% [markdown]
# Question 5 numbers = [1, 5, 10, 15, 20] Using map(), multiply every number by 100.

# %%
numbers = [1, 5, 10, 15, 20]
result = list(map(lambda x: x * 100, numbers))
print(result)
# Out:
# [100, 500, 1000, 1500, 2000]

# %% [markdown]
# Question 6 names = ["ravi", "anil", "meena", "kiran", "sneha"] Using map(), convert every name to uppercase.

# %%
names = ["ravi", "anil", "meena", "kiran", "sneha"]
result = list(map(lambda x: x.upper(), names))
print(result)
# Out:
# ['RAVI', 'ANIL', 'MEENA', 'KIRAN', 'SNEHA']

# %% [markdown]
# Question 7 names = ["RAHUL", "DIVYA", "ARJUN", "AJAY"]Using map(), convert every name to lowercase.

# %%
names = ["RAHUL", "DIVYA", "ARJUN", "AJAY"]
result = list(map(lambda x: x.lower(), names))
print(result)
# Out:
# ['rahul', 'divya', 'arjun', 'ajay']

# %% [markdown]
# Question 8 names = ["rahul kumar", "anil sharma", "meena reddy", "divya singh"] Using map(), convert every name to title case.

# %%
names = ["rahul kumar", "anil sharma", "meena reddy", "divya singh"]
result = list(map(lambda x: x.title(), names))
print(result)
# Out:
# ['Rahul Kumar', 'Anil Sharma', 'Meena Reddy', 'Divya Singh']

# %% [markdown]
# Question 9 words = ["Python", "Azure", "Databricks", "Cloud", "AI"] Using map(), calculate the length of every word.

# %%
words = ["Python", "Azure", "Databricks", "Cloud", "AI"]
result = list(map(lambda x: len(x), words))
print(result)
# Out:
# [6, 5, 10, 5, 2]

# %% [markdown]
# Question 10 words = ["Python", "Azure", "Docker", "Linux", "Spark"] Using map(), extract the first character of every word.

# %%
words = ["Python", "Azure", "Docker", "Linux", "Spark"]
result = list(map(lambda x: x[0], words))
print(result)
# Out:
# ['P', 'A', 'D', 'L', 'S']

# %% [markdown]
# Question 11 words = ["Python", "Azure", "Docker", "Linux", "Spark"] Using map(), extract the last character of every word.

# %%
words = ["Python", "Azure", "Docker", "Linux", "Spark"]
result = list(map(lambda x: x[-1], words))
print(result)
# Out:
# ['n', 'e', 'r', 'x', 'k']

# %% [markdown]
# Question 12 temperatures = [0, 10, 20, 30, 40] Using map(), convert every Celsius temperature into Fahrenheit.

# %%
temperatures = [0, 10, 20, 30, 40]
result = list(map(lambda c: (c * 9/5) + 32, temperatures))
print(result)
# Out:
# [32.0, 50.0, 68.0, 86.0, 104.0]

# %% [markdown]
# Question 13 prices = [100, 250, 500, 1000, 2500] Using map(), calculate 18% GST for every price.

# %%
prices = [100, 250, 500, 1000, 2500]
result = list(map(lambda p: p * 18/100, prices))

print(result)
# Out:
# [18.0, 45.0, 90.0, 180.0, 450.0]

# %% [markdown]
# Question 14 prices = [100, 250, 500, 1000, 2500] Using map(), calculate the final price after adding 18% GST.

# %%
prices = [100, 250, 500, 1000, 2500]
result = list(map(lambda p: p * 1.18, prices))
print(result)
# Out:
# [118.0, 295.0, 590.0, 1180.0, 2950.0]

# %% [markdown]
# Question 15 decimal_numbers = [12.4567, 45.8976, 78.1234, 99.9999] Using map(), round every number to two decimal places.

# %%
decimal_numbers = [12.4567, 45.8976, 78.1234, 99.9999]
result = list(map(lambda x: round(x, 2), decimal_numbers))
print(result)
# Out:
# [12.46, 45.9, 78.12, 100.0]

# %% [markdown]
# Question 16 values = [-10, 20, -35, 40, -55, 60] Using map(), convert every number into its absolute value.

# %%
values = [-10, 20, -35, 40, -55, 60]
result = list(map(lambda x: abs(x), values))
print(result)
# Out:
# [10, 20, 35, 40, 55, 60]

# %% [markdown]
# Question 17 numbers = [10, 20, 30, 40, 50] Using map(), convert every integer into a string.

# %%
numbers = [10, 20, 30, 40, 50]
result = list(map(lambda x: str(x), numbers))
print(result)
# Out:
# ['10', '20', '30', '40', '50']

# %% [markdown]
# Question 18 names = [" Ravi ", " Anil", "Meena ", " Kiran "] Using map(), remove leading and trailing spaces from every name.

# %%
names = [" Ravi ", "Anil", "Meena ", " Kiran "]
result = list(map(lambda x: x.strip(), names))
print(result)
# Out:
# ['Ravi', 'Anil', 'Meena', 'Kiran']

# %% [markdown]
# Question 19 employees = [ {"id": 101, "name": "Rahul", "salary": 45000}, {"id": 102, "name": "Anil", "salary": 65000}, {"id": 103, "name": "Sneha", "salary": 72000}, {"id": 104, "name": "Kiran", "salary": 82000} ] Using map(), extract only employee names.

# %%
employees = [
    {"id": 101, "name": "Rahul", "salary": 45000},
    {"id": 102, "name": "Anil", "salary": 65000},
    {"id": 103, "name": "Sneha", "salary": 72000},
    {"id": 104, "name": "Kiran", "salary": 82000}
]
result = list(map(lambda emp: emp["name"], employees))
print(result)
# Out:
# ['Rahul', 'Anil', 'Sneha', 'Kiran']

# %% [markdown]
# Question 20 employees = [ {"id": 101, "name": "Rahul", "salary": 45000}, {"id": 102, "name": "Anil", "salary": 65000}, {"id": 103, "name": "Sneha", "salary": 72000}, {"id": 104, "name": "Kiran", "salary": 82000} ] Using map(), create a new list of dictionaries containing:
#
# Employee name Original salary Salary after a 10% increment Do not modify the original list.

# %%
employees = [
    {"id": 101, "name": "Rahul", "salary": 45000},
    {"id": 102, "name": "Anil", "salary": 65000},
    {"id": 103, "name": "Sneha", "salary": 72000},
    {"id": 104, "name": "Kiran", "salary": 82000}
]
result = list(map(lambda emp: {
    "name": emp["name"],
    "original_salary": emp["salary"],
    "salary_after_10_percent_increment": emp["salary"] * 1.10
}, employees))
print(result)
# Out:
# [{'name': 'Rahul', 'original_salary': 45000, 'salary_after_10_percent_increment': 49500.00000000001}, {'name': 'Anil', 'original_salary': 65000, 'salary_after_10_percent_increment': 71500.0}, {'name': 'Sneha', 'original_salary': 72000, 'salary_after_10_percent_increment': 79200.0}, {'name': 'Kiran', 'original_salary': 82000, 'salary_after_10_percent_increment': 90200.00000000001}]

# %% [markdown]
# Section 3: filter() — 20 Questions
#
# Question 1 numbers = [12, 45, 67, 89, 23, 56, 91, 34, 78, 100] Using filter(), extract all even numbers.

# %%
numbers = [12, 45, 67, 89, 23, 56, 91, 34, 78, 100]
result = list(filter(lambda x: x % 2 == 0, numbers))
print(result)
# Out:
# [12, 56, 34, 78, 100]

# %% [markdown]
# Question 2 numbers = [12, 45, 67, 89, 23, 56, 91, 34, 78, 100] Using filter(), extract all odd numbers.

# %%
numbers = [12, 45, 67, 89, 23, 56, 91, 34, 78, 100]
result = list(filter(lambda x: x % 2 != 0, numbers))
print(result)
# Out:
# [45, 67, 89, 23, 91]

# %% [markdown]
# Question 3 numbers = [12, 45, 67, 89, 23, 56, 91, 34, 78, 100] Using filter(), extract all numbers greater than 50.

# %%
numbers = [12, 45, 67, 89, 23, 56, 91, 34, 78, 100]
result = list(filter(lambda x: x > 50, numbers))
print(result)
# Out:
# [67, 89, 56, 91, 78, 100]

# %% [markdown]
# Question 4 numbers = [120, 45, 167, 89, 230, 56, 91, 34, 178, 100] Using filter(), extract all numbers less than 100.

# %%
numbers = [120, 45, 167, 89, 230, 56, 91, 34, 178, 100]
result = list(filter(lambda x: x < 100, numbers))
print(result)
# Out:
# [45, 89, 56, 91, 34]

# %% [markdown]
# Question 5 numbers = [-15, -8, 0, 4, 12, -25, 37, 42] Using filter(), extract all positive numbers.

# %%
numbers = [-15, -8, 0, 4, 12, -25, 37, 42]
result = list(filter(lambda x: x > 0, numbers))
print(result)
# Out:
# [4, 12, 37, 42]

# %% [markdown]
# Question 6 numbers = [-15, -8, 0, 4, 12, -25, 37, 42] Using filter(), extract all negative numbers.

# %%
numbers = [-15, -8, 0, 4, 12, -25, 37, 42]
result = list(filter(lambda x: x < 0, numbers))
print(result)
# Out:
# [-15, -8, -25]

# %% [markdown]
# Question 7 numbers = [-15, -8, 0, 4, 12, 0, -25, 37, 0] Using filter(), remove all zero values.

# %%
numbers = [-15, -8, 0, 4, 12, 0, -25, 37, 0]
result = list(filter(lambda x: x != 0, numbers))
print(result)
# Out:
# [-15, -8, 4, 12, -25, 37]

# %% [markdown]
# Question 8 words = ["python", "azure", "ai", "developer", "cloud", "analytics"] Using filter(), extract words containing more than five characters.

# %%
words = ["python", "azure", "ai", "developer", "cloud", "analytics"]
result = list(filter(lambda word: len(word) > 5, words))
print(result)
# Out:
# ['python', 'developer', 'analytics']

# %% [markdown]
# Question 9 names = ["Anil", "Rahul", "Ajay", "Meena", "Arjun", "Kiran", "Akhil"] Using filter(), extract names beginning with "A".

# %%
names = ["Anil", "Rahul", "Ajay", "Meena", "Arjun", "Kiran", "Akhil"]
result = list(filter(lambda name: name.startswith("A"), names))
print(result)
# Out:
# ['Anil', 'Ajay', 'Arjun', 'Akhil']

# %% [markdown]
# Question 10 names = ["Kiran", "Mohan", "Arjun", "Rajan", "Meena", "Varun"] Using filter(), extract names ending with "n".

# %%
names = ["Kiran", "Mohan", "Arjun", "Rajan", "Meena", "Varun"]
result = list(filter(lambda name: name.endswith("n"), names))
print(result)
# Out:
# ['Kiran', 'Mohan', 'Arjun', 'Rajan', 'Varun']

# %% [markdown]
# Question 11 numbers = [10, 15, 18, 20, 25, 30, 32, 40, 45, 50] Using filter(), extract all multiples of 5.

# %%
numbers = [10, 15, 18, 20, 25, 30, 32, 40, 45, 50]
multiples_of_5 = list(filter(lambda x: x % 5 == 0, numbers))
print(multiples_of_5)
# Out:
# [10, 15, 20, 25, 30, 40, 45, 50]

# %% [markdown]
# Question 12 numbers = [3, 5, 10, 15, 18, 30, 42, 45, 60, 75] Using filter(), extract numbers divisible by both 3 and 5.

# %%
numbers = [3, 5, 10, 15, 18, 30, 42, 45, 60, 75]
div_by_3_and_5 = list(filter(lambda x: x % 3 == 0 and x % 5 == 0, numbers))
print(div_by_3_and_5)
# Out:
# [15, 30, 45, 60, 75]

# %% [markdown]
# Question 13 words = ["madam", "python", "level", "azure", "radar", "cloud", "civic"] Using filter(), extract all palindrome words.

# %%
words = ["madam", "python", "level", "azure", "radar", "cloud", "civic"]
palindromes = list(filter(lambda w: w == w[::-1], words))
print(palindromes)
# Out:
# ['madam', 'level', 'radar', 'civic']

# %% [markdown]
# Question 14 emails = [ "john@gmail.com", "rahul@yahoo.com", "admin@python.com", "support@azure.org", "sales@company.com" ] Using filter(), extract email addresses ending with ".com".

# %%
emails = [
    "john@gmail.com",
    "rahul@yahoo.com",
    "admin@python.com",
    "support@azure.org",
    "sales@company.com"
    ]
com_emails = list(filter(lambda e: e.endswith(".com"), emails))
print(com_emails)
# Out:
# ['john@gmail.com', 'rahul@yahoo.com', 'admin@python.com', 'sales@company.com']

# %% [markdown]
# Question 15 files = [ "sales.csv", "employees.xlsx", "products.csv", "report.pdf", "customers.csv", "notes.txt" ] Using filter(), extract all CSV files.

# %%
files = [
    "sales.csv",
    "employees.xlsx",
    "products.csv",
    "report.pdf",
    "customers.csv",
    "notes.txt"
]
csv_files = list(filter(lambda f: f.endswith(".csv"), files))
print(csv_files)
# Out:
# ['sales.csv', 'products.csv', 'customers.csv']

# %% [markdown]
# Question 16 employees = [ {"name": "Rahul", "salary": 45000}, {"name": "Anil", "salary": 65000}, {"name": "Sneha", "salary": 72000}, {"name": "Kiran", "salary": 82000}, {"name": "Meena", "salary": 55000} ] Using filter(), extract employees whose salary is greater than 60000.

# %%
employees = [
    {"name": "Rahul", "salary": 45000},
    {"name": "Anil", "salary": 65000},
    {"name": "Sneha", "salary": 72000},
    {"name": "Kiran", "salary": 82000},
    {"name": "Meena", "salary": 55000}
]
high_paid = list(filter(lambda emp: emp["salary"] > 60000, employees))
print(high_paid)
# Out:
# [{'name': 'Anil', 'salary': 65000}, {'name': 'Sneha', 'salary': 72000}, {'name': 'Kiran', 'salary': 82000}]

# %% [markdown]
# Question 17 students = [ {"name": "Ravi", "marks": 92}, {"name": "Kiran", "marks": 68}, {"name": "Meena", "marks": 85}, {"name": "Ajay", "marks": 48}, {"name": "Sneha", "marks": 79} ] Using filter(), extract students who scored more than 80.

# %%
students = [
    {"name": "Ravi", "marks": 92},
    {"name": "Kiran", "marks": 68},
    {"name": "Meena", "marks": 85},
    {"name": "Ajay", "marks": 48},
    {"name": "Sneha", "marks": 79}
]
top_students = list(filter(lambda s: s["marks"] > 80, students))
print(top_students)
# Out:
# [{'name': 'Ravi', 'marks': 92}, {'name': 'Meena', 'marks': 85}]

# %% [markdown]
# Question 18 products = [ {"name": "Laptop", "price": 55000, "stock": 5}, {"name": "Mouse", "price": 600, "stock": 25}, {"name": "Keyboard", "price": 1500, "stock": 0}, {"name": "Monitor", "price": 18000, "stock": 8}, {"name": "Printer", "price": 12000, "stock": 0} ] Using filter(), extract products that are currently in stock.

# %%
products = [
    {"name": "Laptop", "price": 55000, "stock": 5},
    {"name": "Mouse", "price": 600, "stock": 25},
    {"name": "Keyboard", "price": 1500, "stock": 0},
    {"name": "Monitor", "price": 18000, "stock": 8},
    {"name": "Printer", "price": 12000, "stock": 0}
]
in_stock = list(filter(lambda p: p["stock"] > 0, products))
print(in_stock)
# Out:
# [{'name': 'Laptop', 'price': 55000, 'stock': 5}, {'name': 'Mouse', 'price': 600, 'stock': 25}, {'name': 'Monitor', 'price': 18000, 'stock': 8}]

# %% [markdown]
# Question 19 people = [ {"name": "Rahul", "age": 17}, {"name": "Anil", "age": 25}, {"name": "Sneha", "age": 16}, {"name": "Kiran", "age": 32}, {"name": "Meena", "age": 18} ] Using filter(), extract people who are eligible to vote.

# %%
people = [
    {"name": "Rahul", "age": 17},
    {"name": "Anil", "age": 25},
    {"name": "Sneha", "age": 16},
    {"name": "Kiran", "age": 32},
    {"name": "Meena", "age": 18}
]
eligible_voters = list(filter(lambda p: p["age"] >= 18, people))
print(eligible_voters)
# Out:
# [{'name': 'Anil', 'age': 25}, {'name': 'Kiran', 'age': 32}, {'name': 'Meena', 'age': 18}]

# %% [markdown]
# Question 20 employees = [ {"name": "Rahul", "department": "IT", "active": True}, {"name": "Anil", "department": "HR", "active": True}, {"name": "Sneha", "department": "IT", "active": False}, {"name": "Kiran", "department": "IT", "active": True}, {"name": "Meena", "department": "Sales", "active": True} ] Using filter(), extract employees who belong to the IT department and are active.

# %%
employees = [
    {"name": "Rahul", "department": "IT", "active": True},
    {"name": "Anil", "department": "HR", "active": True},
    {"name": "Sneha", "department": "IT", "active": False},
    {"name": "Kiran", "department": "IT", "active": True},
    {"name": "Meena", "department": "Sales", "active": True}
]
it_active_employees = list(filter(lambda e: e["department"] == "IT" and e["active"], employees))
print(it_active_employees)
# Out:
# [{'name': 'Rahul', 'department': 'IT', 'active': True}, {'name': 'Kiran', 'department': 'IT', 'active': True}]

# %% [markdown]
# Section 4: reduce() — 20 Questions
#
# Question 1 numbers = [10, 20, 30, 40, 50] Using reduce(), calculate the sum of all numbers.

# %%
from functools import reduce
numbers = [10, 20, 30, 40, 50]
total = reduce(lambda x, y: x + y, numbers)
print(total)
# Out:
# 150

# %% [markdown]
# Question 2 numbers = [2, 3, 4, 5] Using reduce(), calculate the product of all numbers.

# %%
from functools import reduce
numbers = [2, 3, 4, 5]
product = reduce(lambda x, y: x * y, numbers)
print(product)
# Out:
# 120

# %% [markdown]
# Question 3 numbers = [45, 12, 89, 34, 67, 91, 28] Using reduce(), find the maximum number.

# %%
from functools import reduce
numbers = [45, 12, 89, 34, 67, 91, 28]
maximum = reduce(lambda x, y: x if x > y else y, numbers)
print(maximum)
# Out:
# 91

# %% [markdown]
# Question 4 numbers = [45, 12, 89, 34, 67, 91, 28] Using reduce(), find the minimum number.

# %%
from functools import reduce
numbers = [45, 12, 89, 34, 67, 91, 28]
minimum = reduce(lambda x, y: x if x < y else y, numbers)
print(minimum)
# Out:
# 12

# %% [markdown]
# Question 5 words = ["Python", " ", "is", " ", "powerful"] Using reduce(), combine all strings into one sentence.

# %%
from functools import reduce
words = ["Python", " ", "is", " ", "powerful"]
sentence = reduce(lambda x, y: x + y, words)
print(sentence)
# Out:
# Python is powerful

# %% [markdown]
# Question 6 words = ["Python", "Azure", "Cloud", "AI"] Using reduce(), calculate the total number of characters in all words.

# %%
from functools import reduce
words = ["Python", "Azure", "Cloud", "AI"]
total_chars = reduce(lambda x, y: x + len(y), words, 0)
print(total_chars)
# Out:
# 18

# %% [markdown]
# Question 7 number = 6 numbers = list(range(1, number + 1)) Using reduce(), calculate the factorial of number.

# %%
from functools import reduce
number = 6
numbers = list(range(1, number + 1))
factorial = reduce(lambda x, y: x * y, numbers)
print(factorial)
# Out:
# 720

# %% [markdown]
# Question 8 numbers = [12, 45, 67, 89, 23, 56, 91, 34, 78, 100] Using reduce(), calculate the sum of only the even numbers. Do not create a separate filtered list.

# %%
from functools import reduce
numbers = [12, 45, 67, 89, 23, 56, 91, 34, 78, 100]
sum_even = reduce(lambda x, y: x + y if y % 2 == 0 else x, numbers, 0)
print(sum_even)
# Out:
# 280

# %% [markdown]
# Question 9 numbers = [12, 45, 67, 89, 23, 56, 91, 34, 78, 100] Using reduce(), calculate the sum of only the odd numbers. Do not create a separate filtered list.

# %%
from functools import reduce
numbers = [12, 45, 67, 89, 23, 56, 91, 34, 78, 100]
sum_odd = reduce(lambda x, y: x + y if y % 2 != 0 else x, numbers, 0)
print(sum_odd)
# Out:
# 315

# %% [markdown]
# Question 10 words = ["AI", "Python", "Databricks", "Cloud", "Kubernetes"] Using reduce(), find the longest word.

# %%
from functools import reduce
words = ["AI", "Python", "Databricks", "Cloud", "Kubernetes"]
longest = reduce(lambda x, y: x if len(x) > len(y) else y, words)
print(longest)
# Out:
# Kubernetes

# %% [markdown]
# Question 11 words = ["AI", "Python", "Databricks", "Cloud", "Kubernetes"] Using reduce(), find the shortest word.

# %%
from functools import reduce
words = ["AI", "Python", "Databricks", "Cloud", "Kubernetes"]
shortest = reduce(lambda x, y: x if len(x) < len(y) else y, words)
print(shortest)
# Out:
# AI

# %% [markdown]
# Question 12 salaries = [45000, 65000, 72000, 82000, 55000] Using reduce(), calculate the total salary.

# %%
from functools import reduce
salaries = [45000, 65000, 72000, 82000, 55000]
total_salary = reduce(lambda x, y: x + y, salaries)
print(total_salary)
# Out:
# 319000

# %% [markdown]
# Question 13 employees = [ {"name": "Rahul", "salary": 45000}, {"name": "Anil", "salary": 65000}, {"name": "Sneha", "salary": 72000}, {"name": "Kiran", "salary": 82000}, {"name": "Meena", "salary": 55000} ] Using reduce(), calculate the total payroll directly from the dictionaries.

# %%
from functools import reduce
employees = [
    {"name": "Rahul", "salary": 45000},
    {"name": "Anil", "salary": 65000},
    {"name": "Sneha", "salary": 72000},
    {"name": "Kiran", "salary": 82000},
    {"name": "Meena", "salary": 55000}
]
total_payroll = reduce(lambda x, y: x + y["salary"], employees, 0)
print(total_payroll)
# Out:
# 319000

# %% [markdown]
# Question 14 employees = [ {"name": "Rahul", "salary": 45000}, {"name": "Anil", "salary": 65000}, {"name": "Sneha", "salary": 72000}, {"name": "Kiran", "salary": 82000}, {"name": "Meena", "salary": 55000} ] Using reduce(), find the employee with the highest salary.

# %%
from functools import reduce
employees = [
    {"name": "Rahul", "salary": 45000},
    {"name": "Anil", "salary": 65000},
    {"name": "Sneha", "salary": 72000},
    {"name": "Kiran", "salary": 82000},
    {"name": "Meena", "salary": 55000}
]
highest_paid = reduce(lambda x, y: x if x["salary"] > y["salary"] else y, employees)
print(highest_paid)
# Out:
# {'name': 'Kiran', 'salary': 82000}

# %% [markdown]
# Question 15 students = [ {"name": "Ravi", "marks": 92}, {"name": "Kiran", "marks": 68}, {"name": "Meena", "marks": 85}, {"name": "Ajay", "marks": 48}, {"name": "Rahul", "marks": 95} ] Using reduce(), find the student with the highest marks.

# %%
from functools import reduce
students = [
    {"name": "Ravi", "marks": 92},
    {"name": "Kiran", "marks": 68},
    {"name": "Meena", "marks": 85},
    {"name": "Ajay", "marks": 48},
    {"name": "Rahul", "marks": 95}
]
topper = reduce(lambda x, y: x if x["marks"] > y["marks"] else y, students)
print(topper)
# Out:
# {'name': 'Rahul', 'marks': 95}

# %% [markdown]
# Question 16 products = [ {"name": "Laptop", "price": 55000, "stock": 5}, {"name": "Mouse", "price": 600, "stock": 25}, {"name": "Keyboard", "price": 1500, "stock": 15}, {"name": "Monitor", "price": 18000, "stock": 8} ] Using reduce(), calculate the total stock quantity.

# %%
from functools import reduce
products = [
    {"name": "Laptop", "price": 55000, "stock": 5},
    {"name": "Mouse", "price": 600, "stock": 25},
    {"name": "Keyboard", "price": 1500, "stock": 15},
    {"name": "Monitor", "price": 18000, "stock": 8}
]
total_stock = reduce(lambda x, y: x + y["stock"], products, 0)
print(total_stock)
# Out:
# 53

# %% [markdown]
# Question 17 products = [ {"name": "Laptop", "price": 55000, "stock": 5}, {"name": "Mouse", "price": 600, "stock": 25}, {"name": "Keyboard", "price": 1500, "stock": 15}, {"name": "Monitor", "price": 18000, "stock": 8} ] Using reduce(), calculate the total inventory value using price × stock.

# %%
from functools import reduce
products = [
    {"name": "Laptop", "price": 55000, "stock": 5},
    {"name": "Mouse", "price": 600, "stock": 25},
    {"name": "Keyboard", "price": 1500, "stock": 15},
    {"name": "Monitor", "price": 18000, "stock": 8}
]
total_value = reduce(lambda x, y: x + y["price"] * y["stock"], products, 0)
print(total_value)
# Out:
# 456500

# %% [markdown]
# Question 18 sales = [12000, 25000, 18000, 45000, 30000, 52000] Using reduce(), calculate the total sales amount.

# %%
from functools import reduce
sales = [12000, 25000, 18000, 45000, 30000, 52000]
total_sales = reduce(lambda x, y: x + y, sales)
print(total_sales)
# Out:
# 182000

# %% [markdown]
# Question 19 dictionaries = [ {"name": "Rahul"}, {"age": 30}, {"department": "IT"}, {"salary": 65000} ] Using reduce(), merge all dictionaries into one dictionary.

# %%
from functools import reduce
dictionaries = [
    {"name": "Rahul"},
    {"age": 30},
    {"department": "IT"},
    {"salary": 65000}
]
merged_dict = reduce(lambda x, y: {**x, **y}, dictionaries)
print(merged_dict)
# Out:
# {'name': 'Rahul', 'age': 30, 'department': 'IT', 'salary': 65000}

# %% [markdown]
# Question 20 numbers = [12, 45, 12, 67, 45, 89, 23, 67, 100] Using reduce(), calculate the sum of unique numbers only. Do not directly use sum(set(numbers)).

# %%
from functools import reduce
numbers = [12, 45, 12, 67, 45, 89, 23, 67, 100]
unique_numbers = reduce(lambda acc, x: acc + [x] if x not in acc else acc, numbers, [])
total_sum = reduce(lambda acc, x: acc + x, unique_numbers, 0)
print("Unique numbers:", unique_numbers)
print("Sum of unique numbers:", total_sum)
# Out:
# Unique numbers: [12, 45, 67, 89, 23, 100]
# Sum of unique numbers: 336

# %% [markdown]
# Section 5: Combined Lambda, map(), filter(), and reduce() — 20 Questions
#
# Question 1 numbers = [12, 45, 67, 89, 23, 56, 91, 34, 78, 100] Using filter() and map():
#
# Extract all even numbers. Calculate the square of every even number. Return the squared values as a list.

# %%
numbers = [12, 45, 67, 89, 23, 56, 91, 34, 78, 100]
evens = filter(lambda x: x % 2 == 0, numbers)
squared_evens = list(map(lambda x: x**2, evens))
print(squared_evens)
# Out:
# [144, 3136, 1156, 6084, 10000]

# %% [markdown]
# Question 2 numbers = [12, 45, 67, 89, 23, 56, 91, 34, 78, 100] Using filter() and reduce():
#
# Extract all odd numbers. Calculate their total sum.

# %%
from functools import reduce
numbers = [12, 45, 67, 89, 23, 56, 91, 34, 78, 100]
odds = filter(lambda x: x % 2 != 0, numbers)
total_odd_sum = reduce(lambda x, y: x + y, odds)
print(total_odd_sum)
# Out:
# 315

# %% [markdown]
# Question 3 numbers = [10, 25, 40, 55, 70, 85, 100] Using filter() and map():
#
# 1.Extract numbers greater than 50. 2.Multiply every selected number by 2.

# %%
numbers = [10, 25, 40, 55, 70, 85, 100]
greater_than_50 = filter(lambda x: x > 50, numbers)
doubled = list(map(lambda x: x * 2, greater_than_50))
print(doubled)
# Out:
# [110, 140, 170, 200]

# %% [markdown]
# Question 4 numbers = [-15, 20, -35, 40, 50, -10, 60] Using filter(), map(), and reduce():
#
# Extract positive numbers. Calculate the square of every positive number. Calculate the total sum of the squared values.

# %%
from functools import reduce
numbers = [-15, 20, -35, 40, 50, -10, 60]
positives = filter(lambda x: x > 0, numbers)
squared = map(lambda x: x**2, positives)
total_sum = reduce(lambda x, y: x + y, squared)
print(total_sum)
# Out:
# 8100

# %% [markdown]
# Question 5 words = ["python", "azure", "ai", "developer", "cloud", "analytics", "spark"] Using filter() and map():
#
# Extract words containing more than five characters. Convert the selected words to uppercase.

# %%
words = ["python", "azure", "ai", "developer", "cloud", "analytics", "spark"]
long_words = filter(lambda w: len(w) > 5, words)
upper_words = list(map(lambda w: w.upper(), long_words))
print(upper_words)
# Out:
# ['PYTHON', 'DEVELOPER', 'ANALYTICS']

# %% [markdown]
# Question 6 names = ["Anil", "Rahul", "Ajay", "Meena", "Arjun", "Kiran", "Akhil"] Using filter() and map():
#
# Extract names beginning with "A". Convert the selected names to lowercase.

# %%
names = ["Anil", "Rahul", "Ajay", "Meena", "Arjun", "Kiran", "Akhil"]
a_names = filter(lambda name: name.startswith("A"), names)
lower_a_names = list(map(lambda name: name.lower(), a_names))
print(lower_a_names)
# Out:
# ['anil', 'ajay', 'arjun', 'akhil']

# %% [markdown]
# Question 7 numbers = [3, 5, 10, 15, 18, 30, 42, 45, 60, 75] Using filter() and reduce():
#
# Extract numbers divisible by both 3 and 5. Calculate their total sum.

# %%
from functools import reduce
numbers = [3, 5, 10, 15, 18, 30, 42, 45, 60, 75]
div_by_3_and_5 = filter(lambda x: x % 3 == 0 and x % 5 == 0, numbers)
total_sum = reduce(lambda x, y: x + y, div_by_3_and_5)
print(total_sum)
# Out:
# 225

# %% [markdown]
# Question 8 words = ["madam", "python", "level", "azure", "radar", "cloud", "civic"] Using filter() and reduce():
#
# Extract palindrome words. Join them into one string separated by " | ".

# %%
from functools import reduce
words = ["madam", "python", "level", "azure", "radar", "cloud", "civic"]
palindromes = filter(lambda w: w == w[::-1], words)
result = reduce(lambda x, y: x + " | " + y, palindromes)
print(result)

# %% [markdown]
# Question 9 temperatures = [18, 24, 30, 35, 40, 12, 28, 33, 15, 42] Using filter(), map(), and reduce():
#
# Extract temperatures greater than 30°C. Convert the selected values into Fahrenheit. Calculate the average Fahrenheit temperature.

# %%
from functools import reduce
temperatures = [18, 24, 30, 35, 40, 12, 28, 33, 15, 42]
above_30 = filter(lambda t: t > 30, temperatures)
to_fahrenheit = map(lambda c: (c * 9/5) + 32, above_30)
fahrenheit_list = list(to_fahrenheit)
total = reduce(lambda x, y: x + y, fahrenheit_list)
average = total / len(fahrenheit_list)
print(fahrenheit_list)
print(round(average, 2))
# Out:
# [95.0, 104.0, 91.4, 107.6]
# 99.5

# %% [markdown]
# Question 10 prices = [450, 1200, 2500, 800, 5000, 1500, 7500] Using filter(), map(), and reduce():
#
# Extract prices greater than 1000. Apply a 10% discount to every selected price. Calculate the total discounted amount.

# %%
from functools import reduce
prices = [450, 1200, 2500, 800, 5000, 1500, 7500]
expensive = filter(lambda p: p > 1000, prices)
discounted = map(lambda p: p * 0.9, expensive)
total_discounted = reduce(lambda x, y: x + y, discounted)
print(list(map(lambda p: p * 0.9, filter(lambda p: p > 1000, prices))))
print(round(total_discounted, 2))
# Out:
# [1080.0, 2250.0, 4500.0, 1350.0, 6750.0]
# 15930.0

# %% [markdown]
# Question 11 employees = [ {"id": 101, "name": "Rahul", "salary": 45000}, {"id": 102, "name": "Anil", "salary": 65000}, {"id": 103, "name": "Sneha", "salary": 72000}, {"id": 104, "name": "Kiran", "salary": 82000}, {"id": 105, "name": "Meena", "salary": 55000} ] Using filter() and map():
#
# Extract employees earning more than 60000. Increase their salary by 10%. Return their names and updated salaries.

# %%
employees = [
    {"id": 101, "name": "Rahul", "salary": 45000},
    {"id": 102, "name": "Anil", "salary": 65000},
    {"id": 103, "name": "Sneha", "salary": 72000},
    {"id": 104, "name": "Kiran", "salary": 82000},
    {"id": 105, "name": "Meena", "salary": 55000}
]
high_earners = filter(lambda e: e["salary"] > 60000, employees)
result = list(map(
    lambda e: {"name": e["name"], "updated_salary": e["salary"] * 1.1},
    high_earners
))
print(result)
# Out:
# [{'name': 'Anil', 'updated_salary': 71500.0}, {'name': 'Sneha', 'updated_salary': 79200.0}, {'name': 'Kiran', 'updated_salary': 90200.00000000001}]

# %% [markdown]
# Question 12 employees = [ {"id": 101, "name": "Rahul", "department": "IT", "salary": 45000}, {"id": 102, "name": "Anil", "department": "HR", "salary": 65000}, {"id": 103, "name": "Sneha", "department": "IT", "salary": 72000}, {"id": 104, "name": "Kiran", "department": "IT", "salary": 82000}, {"id": 105, "name": "Meena", "department": "Sales", "salary": 55000} ] Using filter() and reduce():
#
# Extract employees from the IT department. Calculate the total salary of IT employees.

# %%
from functools import reduce
employees = [
    {"id": 101, "name": "Rahul", "department": "IT", "salary": 45000},
    {"id": 102, "name": "Anil", "department": "HR", "salary": 65000},
    {"id": 103, "name": "Sneha", "department": "IT", "salary": 72000},
    {"id": 104, "name": "Kiran", "department": "IT", "salary": 82000},
    {"id": 105, "name": "Meena", "department": "Sales", "salary": 55000}
]
it_employees = filter(lambda e: e["department"] == "IT", employees)
total_it_salary = reduce(lambda total, e: total + e["salary"], it_employees, 0)
print(total_it_salary)
# Out:
# 199000

# %% [markdown]
# Question 13 employees = [ {"id": 101, "name": "Rahul", "salary": 45000, "active": True}, {"id": 102, "name": "Anil", "salary": 65000, "active": True}, {"id": 103, "name": "Sneha", "salary": 72000, "active": False}, {"id": 104, "name": "Kiran", "salary": 82000, "active": True}, {"id": 105, "name": "Meena", "salary": 55000, "active": True}, {"id": 106, "name": "Arjun", "salary": 98000, "active": False} ] Using filter(), map(), and reduce():
#
# Extract active employees. Increase every active employee's salary by 15%. Calculate the total updated payroll.

# %%
from functools import reduce
employees = [
    {"id": 101, "name": "Rahul", "salary": 45000, "active": True},
    {"id": 102, "name": "Anil", "salary": 65000, "active": True},
    {"id": 103, "name": "Sneha", "salary": 72000, "active": False},
    {"id": 104, "name": "Kiran", "salary": 82000, "active": True},
    {"id": 105, "name": "Meena", "salary": 55000, "active": True},
    {"id": 106, "name": "Arjun", "salary": 98000, "active": False}
]
active_emps = filter(lambda e: e["active"] == True, employees)
updated_salaries = map(lambda e: e["salary"] * 1.15, active_emps)
total_payroll = reduce(lambda x, y: x + y, updated_salaries, 0)
print(round(total_payroll, 2))
# Out:
# 284050.0

# %% [markdown]
# Question 14 students = [ {"name": "Ravi", "marks": 92, "passed": True}, {"name": "Kiran", "marks": 68, "passed": True}, {"name": "Meena", "marks": 85, "passed": True}, {"name": "Ajay", "marks": 48, "passed": True}, {"name": "Sneha", "marks": 35, "passed": False}, {"name": "Rahul", "marks": 95, "passed": True} ] Using filter() and reduce():
#
# Extract students who passed. Find the topper among the passed students.

# %%
from functools import reduce
students = [
    {"name": "Ravi", "marks": 92, "passed": True},
    {"name": "Kiran", "marks": 68, "passed": True},
    {"name": "Meena", "marks": 85, "passed": True},
    {"name": "Ajay", "marks": 48, "passed": True},
    {"name": "Sneha", "marks": 35, "passed": False},
    {"name": "Rahul", "marks": 95, "passed": True}
]
passed_students = filter(lambda s: s["passed"] == True, students)
topper = reduce(lambda x, y: x if x["marks"] > y["marks"] else y, passed_students)
print(topper)
# Out:
# {'name': 'Rahul', 'marks': 95, 'passed': True}

# %% [markdown]
# Question 15 students = [ {"name": "Ravi", "marks": 92}, {"name": "Kiran", "marks": 68}, {"name": "Meena", "marks": 85}, {"name": "Ajay", "marks": 48}, {"name": "Sneha", "marks": 79}, {"name": "Rahul", "marks": 95} ] Using filter(), map(), and reduce():
#
# Extract students scoring more than 70. Extract only their marks. Calculate the average marks.

# %%
from functools import reduce
students = [
    {"name": "Ravi", "marks": 92},
    {"name": "Kiran", "marks": 68},
    {"name": "Meena", "marks": 85},
    {"name": "Ajay", "marks": 48},
    {"name": "Sneha", "marks": 79},
    {"name": "Rahul", "marks": 95}
]
high_scorers = filter(lambda s: s["marks"] > 70, students)
marks = list(map(lambda s: s["marks"], high_scorers))
total = reduce(lambda x, y: x + y, marks, 0)
average = total / len(marks)
print("Marks > 70:", marks)
print("Average:", round(average, 2))
# Out:
# Marks > 70: [92, 85, 79, 95]
# Average: 87.75

# %% [markdown]
# Question 16 products = [ {"name": "Laptop", "price": 55000, "stock": 5}, {"name": "Mouse", "price": 600, "stock": 25}, {"name": "Keyboard", "price": 1500, "stock": 0}, {"name": "Monitor", "price": 18000, "stock": 8}, {"name": "Printer", "price": 12000, "stock": 0}, {"name": "SSD", "price": 6500, "stock": 12} ] Using filter(), map(), and reduce():
#
# Extract products currently in stock. Calculate each product's inventory value using price × stock. Calculate the total inventory value.

# %%
from functools import reduce
products = [
    {"name": "Laptop", "price": 55000, "stock": 5},
    {"name": "Mouse", "price": 600, "stock": 25},
    {"name": "Keyboard", "price": 1500, "stock": 0},
    {"name": "Monitor", "price": 18000, "stock": 8},
    {"name": "Printer", "price": 12000, "stock": 0},
    {"name": "SSD", "price": 6500, "stock": 12}
]
in_stock = filter(lambda p: p["stock"] > 0, products)
inventory_values = list(map(lambda p: {"name": p["name"], "value": p["price"] * p["stock"]}, in_stock))
total_value = reduce(lambda total, p: total + p["value"], inventory_values, 0)
print("Inventory values:", inventory_values)
print("Total Inventory Value:", total_value)
# Out:
# Inventory values: [{'name': 'Laptop', 'value': 275000}, {'name': 'Mouse', 'value': 15000}, {'name': 'Monitor', 'value': 144000}, {'name': 'SSD', 'value': 78000}]
# Total Inventory Value: 512000

# %% [markdown]
# Question 17 products = [ {"name": "Laptop", "price": 55000, "category": "Electronics"}, {"name": "Chair", "price": 4500, "category": "Furniture"}, {"name": "Monitor", "price": 18000, "category": "Electronics"}, {"name": "Desk", "price": 8500, "category": "Furniture"}, {"name": "SSD", "price": 6500, "category": "Electronics"} ] Using filter(), map(), and reduce():
#
# Extract products belonging to the Electronics category. Apply a 20% discount. Calculate the total discounted value.

# %%
from functools import reduce
products = [
    {"name": "Laptop", "price": 55000, "category": "Electronics"},
    {"name": "Chair", "price": 4500, "category": "Furniture"},
    {"name": "Monitor", "price": 18000, "category": "Electronics"},
    {"name": "Desk", "price": 8500, "category": "Furniture"},
    {"name": "SSD", "price": 6500, "category": "Electronics"}
]
electronics = filter(lambda p: p["category"] == "Electronics", products)
discounted = list(map(lambda p: {"name": p["name"], "discounted_price": p["price"] * 0.8}, electronics))
total_discounted = reduce(lambda total, p: total + p["discounted_price"], discounted, 0)
print("Discounted Electronics:", discounted)
print("Total Discounted Value:", total_discounted)
# Out:
# Discounted Electronics: [{'name': 'Laptop', 'discounted_price': 44000.0}, {'name': 'Monitor', 'discounted_price': 14400.0}, {'name': 'SSD', 'discounted_price': 5200.0}]
# Total Discounted Value: 63600.0

# %% [markdown]
# Question 18 orders = [ {"order_id": 1001, "amount": 1200, "status": "Delivered"}, {"order_id": 1002, "amount": 3500, "status": "Pending"}, {"order_id": 1003, "amount": 8500, "status": "Delivered"}, {"order_id": 1004, "amount": 4200, "status": "Cancelled"}, {"order_id": 1005, "amount": 7600, "status": "Delivered"}, {"order_id": 1006, "amount": 5100, "status": "Pending"} ] Using filter() and reduce():
#
# Extract delivered orders. Calculate the total delivered revenue.

# %%
from functools import reduce
orders = [
    {"order_id": 1001, "amount": 1200, "status": "Delivered"},
    {"order_id": 1002, "amount": 3500, "status": "Pending"},
    {"order_id": 1003, "amount": 8500, "status": "Delivered"},
    {"order_id": 1004, "amount": 4200, "status": "Cancelled"},
    {"order_id": 1005, "amount": 7600, "status": "Delivered"},
    {"order_id": 1006, "amount": 5100, "status": "Pending"}
]
delivered_orders = filter(lambda o: o["status"] == "Delivered", orders)
total_revenue = reduce(lambda total, o: total + o["amount"], delivered_orders, 0)
print("Total Delivered Revenue:", total_revenue)
# Out:
# Total Delivered Revenue: 17300

# %% [markdown]
# Question 19 transactions = [ {"id": 1, "amount": 1200}, {"id": 2, "amount": 5200}, {"id": 3, "amount": 18000}, {"id": 4, "amount": 2500}, {"id": 5, "amount": 9600}, {"id": 6, "amount": 7200} ] Using filter(), map(), and reduce():
#
# Extract transactions whose amount is greater than 5000. Add 18% GST to every selected transaction. Calculate the grand total after GST.

# %%
from functools import reduce
transactions = [
    {"id": 1, "amount": 1200},
    {"id": 2, "amount": 5200},
    {"id": 3, "amount": 18000},
    {"id": 4, "amount": 2500},
    {"id": 5, "amount": 9600},
    {"id": 6, "amount": 7200}
]
high_value = filter(lambda t: t["amount"] > 5000, transactions)
with_gst = list(map(lambda t: {"id": t["id"], "amount_with_gst": t["amount"] * 1.18}, high_value))
grand_total = reduce(lambda total, t: total + t["amount_with_gst"], with_gst, 0)
print("Transactions with GST:", with_gst)
print("Grand Total:", round(grand_total, 2))
# Out:
# Transactions with GST: [{'id': 2, 'amount_with_gst': 6136.0}, {'id': 3, 'amount_with_gst': 21240.0}, {'id': 5, 'amount_with_gst': 11328.0}, {'id': 6, 'amount_with_gst': 8496.0}]
# Grand Total: 47200.0

# %% [markdown]
# Question 20 sales_records = [ {"salesperson": "Rahul", "region": "South", "sales": 45000, "active": True}, {"salesperson": "Anil", "region": "North", "sales": 65000, "active": True}, {"salesperson": "Sneha", "region": "South", "sales": 72000, "active": False}, {"salesperson": "Kiran", "region": "South", "sales": 82000, "active": True}, {"salesperson": "Meena", "region": "West", "sales": 55000, "active": True}, {"salesperson": "Arjun", "region": "South", "sales": 98000, "active": True} ] Using filter(), map(), and reduce():
#
# Extract active salespeople from the South region. Calculate a 5% incentive for each selected salesperson. Create a list containing salesperson name, sales amount, and incentive. Calculate the total incentive payable.

# %%
from functools import reduce
sales_records = [
    {"salesperson": "Rahul", "region": "South", "sales": 45000, "active": True},
    {"salesperson": "Anil", "region": "North", "sales": 65000, "active": True},
    {"salesperson": "Sneha", "region": "South", "sales": 72000, "active": False},
    {"salesperson": "Kiran", "region": "South", "sales": 82000, "active": True},
    {"salesperson": "Meena", "region": "West", "sales": 55000, "active": True},
    {"salesperson": "Arjun", "region": "South", "sales": 98000, "active": True}
]
south_active = filter(lambda s: s["region"] == "South" and s["active"] == True, sales_records)
incentive_list = list(map(lambda s: {
    "salesperson": s["salesperson"],
    "sales": s["sales"],
    "incentive": s["sales"] * 0.05
}, south_active))
total_incentive = reduce(lambda total, s: total + s["incentive"], incentive_list, 0)

print("Incentive List:", incentive_list)
print("Total Incentive Payable:", total_incentive)
# Out:
# Incentive List: [{'salesperson': 'Rahul', 'sales': 45000, 'incentive': 2250.0}, {'salesperson': 'Kiran', 'sales': 82000, 'incentive': 4100.0}, {'salesperson': 'Arjun', 'sales': 98000, 'incentive': 4900.0}]
# Total Incentive Payable: 11250.0
